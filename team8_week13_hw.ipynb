# %% [markdown]
# <a href="https://colab.research.google.com/github/JouChenLiu/DS_teamproject_team8/blob/main/team8_week13_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O taipei_sans_tc_beta.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download

import matplotlib
# 新增字體
matplotlib.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')

# 將 font-family 設為 Taipei Sans TC Beta
# 設定完後，之後的圖表都可以顯示中文了
matplotlib.rc('font', family='Taipei Sans TC Beta')
# Out:
# --2022-11-28 15:22:07--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 74.125.139.113, 74.125.139.139, 74.125.139.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.139.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t0cl1bvoggo194hdok82but95v55sr72/1669648875000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=97e2334f-6040-4af3-9c0b-ce7b4b19405b [following]
# Warning: wildcards not supported in HTTP.
# --2022-11-28 15:22:11--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t0cl1bvoggo194hdok82but95v55sr72/1669648875000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=97e2334f-6040-4af3-9c0b-ce7b4b19405b
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 74.125.196.132, 2607:f8b0:400c:c36::84
# Connecting to doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)|74.125.196.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/x-font-ttf]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# taipei_sans_tc_beta 100%[===================>]  19.70M  37.0MB/s    in 0.5s
#
# 2022-11-28 15:22:12 (37.0 MB/s) - ‘taipei_sans_tc_beta.ttf’ saved [20659344/20659344]

# %%
from datascience import *
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

print([f for f in matplotlib.font_manager.fontManager.ttflist if 'Heiti' in f.name])
# matplotlib.rcParams['font.family'] = ['Heiti TC']
# Out:
# []

# %%
# table_106_108 = Table().read_table('https://data.tycg.gov.tw/opendata/datalist/datasetMeta/download?id=97b95750-c80c-4f4b-8ae0-b14191b5d846&rid=c39c342d-6f62-4745-96dc-428730d24754')
# table_106_108

# %%
table_109= Table().read_table('https://data.tycg.gov.tw/opendata/datalist/datasetMeta/download?id=77c34235-6fd9-4c1f-8ebd-1f675cdc7c02&rid=3fa9285a-b5f5-4f20-91e2-b628fcc489ac')
table_109

# %%
table_110= Table().read_table('https://data.tycg.gov.tw/opendata/datalist/datasetMeta/download?id=ae5d2d9b-59ad-4f15-a9d2-d0f5f3de2475&rid=8b93ee39-5f31-4807-bdfb-4da6bb71db4b')
table_110
# Out:
# 發生日期     | 發生時間 | 發生年度 | 發生月份 | 發生星期 | 到場處理日期   | 到場處理時間 | 結束_事故排除_日期 | 結束_事故排除_時間 | GPS經度   | GPS緯度   | 事故類別名稱 | 地址類型名稱 | 發生縣市名稱 | 發生市區鄉鎮名稱 | 發生地址_村里代碼 | 發生地址_村里名稱 | 發生地址_鄰 | 發生地址_路街代碼 | 發生地址_路街 | 發生地址_段 | 發生地址_巷 | 發生地址_弄 | 發生地址_號 | 發生地址_前幾公尺 | 發生地址_側名稱 | 發生交叉路口_村里名稱 | 發生交叉路口_路街口 | 發生交叉路口_段 | 發生交叉路口_巷 | 發生交叉路口_弄 | 發生地址_其他  | 死亡人數_24小時內 | 死亡人數_2_30日內 | 受傷人數 | 天候代碼 | 天候名稱 | 光線代碼 | 光線名稱              | 道路第1當事者_代碼 | 道路第1當事者_名稱 | 速限_第1當事者 | 道路型態大類別代碼 | 道路型態大類別名稱 | 道路型態子類別代碼 | 道路型態子類別名稱 | 事故位置大類別代碼 | 事故位置大類別名稱 | 事故位置子類別代碼 | 事故位置子類別名稱 | 路面狀況_路面鋪裝代碼 | 路面狀況_路面鋪裝名稱 | 路面狀況_路面狀態代碼 | 路面狀況_路面狀態名稱 | 路面狀況_路面缺陷代碼 | 路面狀況_路面缺陷名稱 | 道路障礙_障礙物代碼 | 道路障礙_障礙物名稱 | 道路障礙_視距品質代碼 | 道路障礙_視距品質名稱 | 道路障礙_視距代碼 | 道路障礙_視距名稱 | 號誌_號誌種類代碼 | 號誌_號誌種類名稱        | 號誌_號誌動作代碼 | 號誌_號誌動作名稱 | 車道劃分設施_分向設施大類別代碼 | 車道劃分設施_分向設施大類別名稱 | 車道劃分設施_分向設施子類別代碼 | 車道劃分設施_分向設施子類別名稱 | 車道劃分設施_快車道或一般車道間代碼 | 車道劃分設施_快車道或一般車道間名稱 | 車道劃分設施_快慢車道間代碼 | 車道劃分設施_快慢車道間名稱 | 車道劃分設施_路面邊線代碼 | 車道劃分設施_路面邊線名稱 | 事故類型及型態大類別代碼 | 事故類型及型態大類別名稱 | 事故類型及型態子類別代碼 | 事故類型及型態子類別名稱 | 肇因研判大類別代碼_主要 | 肇因研判大類別名稱_主要 | 肇因研判子類別代碼_主要 | 肇因研判子類別名稱_主要 | 當事者順位 | 國籍   | 當事者屬性別名稱 | 當事者事故發生時年齡 | 牌照種類代碼 | 牌照種類名稱 | 乘坐車輛的牌照種類代碼 | 乘坐車輛的牌照種類名稱 | 乘坐車輛的當事者區分_大類別代碼_車種 | 乘坐車輛的當事者區分_大類別名稱_車種 | 乘坐車輛的當事者區分_子類別代碼_車種 | 乘坐車輛的當事者區分_子類別名稱_車種 | 受傷程度代碼 | 受傷程度名稱 | 主要傷處代碼 | 主要傷處名稱 | 保護裝備代碼 | 保護裝備名稱             | 行動電話_電腦或其他相類功能裝置代碼 | 行動電話_電腦或其他相類功能裝置名稱 | 車輛用途代碼 | 車輛用途名稱 | 當事者行動狀態大類別代碼 | 當事者行動狀態大類別名稱 | 當事者行動狀態子類別代碼 | 當事者行動狀態子類別名稱 | 駕駛資格情形代碼 | 駕駛資格情形名稱  | 駕駛執照種類大類別代碼 | 駕駛執照種類大類別名稱 | 駕駛執照種類子類別代碼 | 駕駛執照種類子類別名稱 | 飲酒情形代碼 | 飲酒情形名稱   | 車輛撞擊部位大類別代碼_最初 | 車輛撞擊部位大類別名稱_最初 | 車輛撞擊部位子類別代碼_最初 | 車輛撞擊部位子類別名稱_最初 | 車輛撞擊部位大類別代碼_其他 | 車輛撞擊部位大類別名稱_其他 | 車輛撞擊部位子類別代碼_其他 | 車輛撞擊部位子類別名稱_其他 | 肇因研判大類別代碼_個別 | 肇因研判大類別名稱_個別 | 肇因研判子類別代碼_個別 | 肇因研判子類別名稱_個別 | 肇事逃逸類別代碼_是否肇逃 | 肇事逃逸類別名稱_是否肇逃 | 職業代碼 | 職業名稱 | 旅次目的代碼 | 旅次目的名稱
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 1     | 1    | 女        | 26         | H      | 重機     | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 1                  | 未使用                | 7      | 其他     | 1            | 車的狀態         | 5            | 左轉彎          | 1        | 有適當之駕照    | 3           | 機車駕照        | 10          | 普通重型        | 2      | 經檢測無酒精反應 | 2              | 機車             | 11             | 前車頭            | nan            |                | nan            |                | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 2     | 1    | 女        | 58         | H      | 重機     | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 1                  | 未使用                | 7      | 其他     | 1            | 車的狀態         | 9            | 向前直行中        | 1        | 有適當之駕照    | 3           | 機車駕照        | 10          | 普通重型        | 2      | 經檢測無酒精反應 | 2              | 機車             | 14             | 左側車身           | nan            |                | nan            |                | 5            | 無(車輛駕駛人因素)   | 44           | 尚未發現肇事因素     | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 3     | 1    | 男        | 20         |        |        | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 5                  | 非駕駛人               | 7      | 其他     | 2            | 人的狀態         | 20           | 其他           | 8        | 非汽(機)車駕駛人 | 5           | 其他          | 20          | 非汽(機)車駕駛人   | 10     | 非駕駛人，未檢測 | 3              | 其他             | 16             | 非汽(機)車         | nan            |                | nan            |                | 7            | 行人(或乘客)      | 60           | 其他引起事故之疏失或行為 | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 4     | 1    | 男        | 58         |        |        | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 5                  | 非駕駛人               | 7      | 其他     | 2            | 人的狀態         | 20           | 其他           | 8        | 非汽(機)車駕駛人 | 5           | 其他          | 20          | 非汽(機)車駕駛人   | 10     | 非駕駛人，未檢測 | 3              | 其他             | 16             | 非汽(機)車         | nan            |                | nan            |                | 7            | 行人(或乘客)      | 60           | 其他引起事故之疏失或行為 | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 1     | 1    | 女        | 26         | H      | 重機     | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 1                  | 未使用                | 7      | 其他     | 1            | 車的狀態         | 5            | 左轉彎          | 1        | 有適當之駕照    | 3           | 機車駕照        | 10          | 普通重型        | 2      | 經檢測無酒精反應 | 2              | 機車             | 11             | 前車頭            | nan            |                | nan            |                | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 2     | 1    | 女        | 58         | H      | 重機     | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 1                  | 未使用                | 7      | 其他     | 1            | 車的狀態         | 9            | 向前直行中        | 1        | 有適當之駕照    | 3           | 機車駕照        | 10          | 普通重型        | 2      | 經檢測無酒精反應 | 2              | 機車             | 14             | 左側車身           | nan            |                | nan            |                | 5            | 無(車輛駕駛人因素)   | 44           | 尚未發現肇事因素     | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 3     | 1    | 男        | 20         |        |        | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 5                  | 非駕駛人               | 7      | 其他     | 2            | 人的狀態         | 20           | 其他           | 8        | 非汽(機)車駕駛人 | 5           | 其他          | 20          | 非汽(機)車駕駛人   | 10     | 非駕駛人，未檢測 | 3              | 其他             | 16             | 非汽(機)車         | nan            |                | nan            |                | 7            | 行人(或乘客)      | 60           | 其他引起事故之疏失或行為 | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1600 | 2021 | 1    | 五    | 20210101 | 2600   | 20210101   | 4100       | 121.248 | 24.9571 | A2     | 交叉路口   | 桃園市    | 中壢區      | nan       |           | nan    | 6.8e+15   | 環中東路    | nan    |        | nan    |        | 0         | 口        |             | 新中北路       | nan      |          | nan      |          | 0          | 0           | 4    | 7    | 陰    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 2         | 行車管制號誌(附設行人專用號誌) | 1         | 正常        | 1                | 中央分向島            | 1                | ?式(50公分以上)       | 4                  | 車道線(無標記)           | 5              | 未繪設快慢車道分隔線     | 1             | 有             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 8            | 左轉彎未依規定      | 4     | 1    | 男        | 58         |        |        | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 5                  | 非駕駛人               | 7      | 其他     | 2            | 人的狀態         | 20           | 其他           | 8        | 非汽(機)車駕駛人 | 5           | 其他          | 20          | 非汽(機)車駕駛人   | 10     | 非駕駛人，未檢測 | 3              | 其他             | 16             | 非汽(機)車         | nan            |                | nan            |                | 7            | 行人(或乘客)      | 60           | 其他引起事故之疏失或行為 | 1             | 否             | 22   | 不明   | 8      | 其他
# 20210101 | 1800 | 2021 | 1    | 五    | 20210101 | 2800   | 20210101   | 12000      | 121.294 | 24.9911 | A2     | 其他     | 桃園市    | 桃園區      | nan       |           | nan    | nan       |         | nan    |        | nan    |        | 0         |          |             |            | nan      |          | nan      | 中山路泰昌三街口 | 0          | 0           | 1    | 8    | 晴    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 1         | 行車管制號誌           | 1         | 正常        | 5                | 無                | 10               | 無分向設施            | 5                  | 未繪設車道線             | 5              | 未繪設快慢車道分隔線     | 2             | 無             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 25           | 違反號誌管制或指揮    | 1     | 1    | 男        | 53         | A      | 汽車     | A           | 汽車          | B0                  | 小客車                 | B01                 | 計程車                 | 3      | 未受傷    | 10     | 無      | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 4                  | 不明                 | 7      | 其他     | 1            | 車的狀態         | 5            | 左轉彎          | 1        | 有適當之駕照    | 1           | 職業駕照        | 3           | 大貨車         | 2      | 經檢測無酒精反應 | 1              | 汽車             | 1              | 前車頭            | nan            |                | nan            |                | 1            | 駕駛人          | 25           | 違反號誌管制或指揮    | 1             | 否             | 21   | 其他   | 8      | 其他
# 20210101 | 1800 | 2021 | 1    | 五    | 20210101 | 2800   | 20210101   | 12000      | 121.294 | 24.9911 | A2     | 其他     | 桃園市    | 桃園區      | nan       |           | nan    | nan       |         | nan    |        | nan    |        | 0         |          |             |            | nan      |          | nan      | 中山路泰昌三街口 | 0          | 0           | 1    | 8    | 晴    | 3    | 夜間(或隧道、地下道、涵洞)有照明 | 5          | 市區道路       | 50       | 2         | 交岔路       | 4         | 四岔路       | 1         | 交叉路口      | 1         | 交叉路口內     | 1           | 柏油          | 5           | 乾燥          | 4           | 無缺陷         | 5          | 無障礙物       | 2           | 良好          | 7         | 良好        | 1         | 行車管制號誌           | 1         | 正常        | 5                | 無                | 10               | 無分向設施            | 5                  | 未繪設車道線             | 5              | 未繪設快慢車道分隔線     | 2             | 無             | 2            | 車與車          | 16           | 側撞           | 1            | 駕駛人          | 25           | 違反號誌管制或指揮    | 2     | 1    | 女        | 36         | H      | 重機     | H           | 重機          | C0                  | 機車                  | C03                 | 普通重型                | 2      | 受傷     | 9      | 多數傷    | 1      | 戴安全帽或繫安全帶(使用幼童安全椅) | 4                  | 不明                 | 7      | 其他     | 1            | 車的狀態         | 9            | 向前直行中        | 1        | 有適當之駕照    | 3           | 機車駕照        | 10          | 普通重型        | 2      | 經檢測無酒精反應 | 2              | 機車             | 14             | 左側車身           | nan            |                | nan            |                | 5            | 無(車輛駕駛人因素)   | 44           | 尚未發現肇事因素     | 1             | 否             | 21   | 其他   | 8      | 其他
# ... (92240 rows omitted)

# %%
table_110n=table_110.select(['發生日期','當事者屬性別名稱','當事者事故發生時年齡','發生市區鄉鎮名稱','事故類型及型態大類別名稱','肇因研判大類別名稱_個別','受傷人數','死亡人數_24小時內','死亡人數_2_30日內','飲酒情形名稱'])
#要用

# %%
table_109n=table_109.select(['發生日期','當事者屬性別名稱','當事者事故發生時年齡','發生市區鄉鎮名稱','事故類型及型態大類別名稱','肇因研判大類別名稱_個別','受傷人數','死亡人數_24小時內','死亡人數_2_30日內','飲酒情形名稱'])

# %% [markdown]
# 桃園市各區 事故位置類別 數量

# %% [markdown]
# 目標loc_110_total
# * x橫的標題放'發生市區鄉鎮名稱' '(事故位置子類別名稱)'.....(共1+19欄)[目前看到最多事故位置子類別有19種(中壢區) 其它區不到19種]
# * y縱的標題放'(發生市區鄉鎮名稱)'
#             中壢區(loc[0])
#             八德區(loc[1])
#             ...
#             (共13個區)(loc[12])
#
# arr: 即x橫的標題(以中壢區來看 為1+19個欄位)
# a[0 for i in range(13)]: total[i].column(1)         即事故位置table(含事故位置名稱&group的數量) 的column(1) array(純的事故位置group數量)
# a2[0 for i in range(13)]: np.append(loc[i], a[i])   即作為loc_110_total向下延伸 橫的array('中壢區' '(事故位置group數量)' '(事故位置group數量)'...'(事故位置group數量)')
#
# So, 其實各區應該先印出全部的事故位置table(含事故位置名稱&group的數量) 即total[0 for i in range(13)]
# 這樣才能整個整合XD
# => 要對應正確的事故位置名稱 而不是直接向下延伸rows(橫的)

# %%
# 各區域+事故位置類別
location_110 = table_110.select(['發生市區鄉鎮名稱','事故位置子類別名稱'])
location_110
# Out:
# 發生市區鄉鎮名稱 | 事故位置子類別名稱
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 中壢區      | 交叉路口內
# 桃園區      | 交叉路口內
# 桃園區      | 交叉路口內
# ... (92240 rows omitted)

# %%
# 各區域事故數量
location_110_total = table_110.group('發生市區鄉鎮名稱')
location_110_total
# Out:
# 發生市區鄉鎮名稱 | count
# 中壢區      | 20546
# 八德區      | 9257
# 大園區      | 3600
# 大溪區      | 3740
# 平鎮區      | 8604
# 復興區      | 227
# 新屋區      | 1621
# 桃園區      | 17344
# 楊梅區      | 5419
# 蘆竹區      | 6850
# ... (3 rows omitted)

# %%
# <各區域><事故位置類別> 數量統計表
loc = [0 for i in range(13)]
total = [0 for i in range(13)]
a = [0 for i in range(13)]
a2 = [0 for i in range(13)]
pd = [0 for i in range(13)]

for i in range(13):
    loc[i] = location_110_total.column(0).item(i)
    total[i] = location_110.where('發生市區鄉鎮名稱',are.equal_to(loc[i])).group('事故位置子類別名稱')
    pd[i] = ((total[i].to_df()).rename(columns={'count':loc[i]})).set_index('事故位置子類別名稱')

for i in range(12):
    loc_110_total = pd[i].join(pd[i+1], how='outer')
    pd[i+1] = loc_110_total
loc_110_total = loc_110_total.astype('Int64') # float轉int
loc_110_total
# loc_110_total_T = loc_110_total.T # 轉置(x,y軸交換)
# loc_110_total_T
# Out:
#                 中壢區   八德區   大園區   大溪區   平鎮區   復興區   新屋區   桃園區   楊梅區   蘆竹區  \
# 事故位置子類別名稱
# 一般車道(未劃分快慢車道)  7211  3404  1494  1796  2450   203   710  5739  2453  2797
# 交叉口附近          2921  1673   517   750  1622  <NA>   126  2389   634   605
# 交叉路口內          9056  3675  1205   889  3466     8   617  8064  1806  2800
# 交通島(含槽化線)        26     6     4    11    23     2  <NA>    17     8     2
# 人行道              51    10     2     3     4  <NA>     2    88    10    27
# 公車專用道             4  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>     4  <NA>  <NA>
# 其他              345    55    27    17   122     8    22   113   220    58
# 加速車道              2     4  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>     2
# 快車道             134    96    66    34   190  <NA>    33   134    58    92
# 慢車道             339   147    74    88   266  <NA>    30   299    71   137
# 機車停等區            79    20    15    15    38  <NA>     2    67     9     8
# 機車優先道            16    30    45     7    91  <NA>    20    38    14    42
# 機車專用道            39     8    14    16    51  <NA>  <NA>    56     6    23
# 機車待轉區            12    19  <NA>     8    12  <NA>  <NA>    23  <NA>     2
# 環道匝道              2  <NA>  <NA>  <NA>     4  <NA>  <NA>  <NA>  <NA>  <NA>
# 直線匝道           <NA>     2     4     6    16  <NA>  <NA>  <NA>  <NA>  <NA>
# 穿越道附近             2  <NA>  <NA>  <NA>  <NA>  <NA>  <NA>     5  <NA>  <NA>
# 行人穿越道            94    27     6    16    20  <NA>     2   114    17    33
# 路肩、路緣           211    81   127    82   221     6    57   192   113   220
# 迴轉道               2  <NA>  <NA>     2     8  <NA>  <NA>     2  <NA>     2
#
#                 觀音區   龍潭區   龜山區
# 事故位置子類別名稱
# 一般車道(未劃分快慢車道)   847  1574  3717
# 交叉口附近           198   434  1447
# 交叉路口內           978  1727  2706
# 交通島(含槽化線)         7     7    13
# 人行道            <NA>     3    36
# 公車專用道          <NA>  <NA>     2
# 其他                6     4    38
# 加速車道              2     2     4
# 快車道              81    45    90
# 慢車道              88    80   384
# 機車停等區             4    16    28
# 機車優先道            12     9    39
# 機車專用道             2     6     4
# 機車待轉區             2     2    12
# 環道匝道              2  <NA>  <NA>
# 直線匝道              3  <NA>     2
# 穿越道附近          <NA>  <NA>  <NA>
# 行人穿越道             4    20    18
# 路肩、路緣           124    91   120
# 迴轉道            <NA>  <NA>     2

# %%
# 單一區域 橫直方圖
# total[0]: 中壢區"事故位置子類別"數量統計表
for i in range(13):
  total_bar = ((total[i].to_df()).rename(columns={'count':loc[i]})).set_index('事故位置子類別名稱')
  total_bar.plot.barh(title='110年桃園市'+loc[i]+'事故發生市區_位置類別名稱件數', figsize=(15,10))
  plt.show()

# %%
# 單一區域 圓餅圖
for i in range(13):
  total_bar = ((total[i].to_df()).rename(columns={'count':loc[i]})).set_index('事故位置子類別名稱')
  total_bar.plot.pie(title='110年桃園市事故發生市區_位置類別名稱件數', subplots=True, autopct='%.1f', fontsize=12, figsize=(20,15))
  plt.show()

# %%
# 這格失敗...
# 單一區域 散點圖
# for i in range(13):
#   total_bar = ((total[i].to_df()).rename(columns={'count':loc[i]})).set_index('事故位置子類別名稱')
#   total_bar.plot.scatter(title='110年桃園市'+loc[i]+'事故發生市區_位置類別名稱件數', x='發生市區鄉鎮名稱', y='發生市區鄉鎮名稱', figsize=(15,10))
#   plt.show()

# %%
# # 全部區域 直方圖
# # loc_110_total.plot.bar(title='110年桃園市事故發生市區_位置類別名稱件數', figsize=(20,15))  # 事故位置類別名稱
# loc_110_total_T.plot.barh(title='110年桃園市事故發生市區_位置類別名稱件數', figsize=(20,100))  # x軸為市區名稱
# plt.show()

# %%
# # 全部區域 折線圖
# # loc_110_total.plot(title='110年桃園市事故發生市區_位置類別名稱件數',
# #               xlabel='事故位置子類別名稱',
# #               ylabel='事故發生市區',
# #               legend=True,  # 是否顯示圖例
# #               figsize=(20,10))

# loc_110_total_T.plot(title='110年桃園市事故發生市區_位置類別名稱件數',
#               xlabel='事故發生市區',
#               ylabel='事故位置子類別名稱',
#               legend=True,  # 是否顯示圖例
#               figsize=(20,10))

# plt.show()

# %%
# # 這格失敗....

# # 全部區域 散點圖
# # import seaborn as sns
# # sns.set_theme(style='whitegrid')
# # sns.relplot(data = loc_110_total,
# #           x='事故位置子類別名稱',
# #           y='事故件數',
# #           hue='發生市區鄉鎮名稱',
# #           size='事故件數',
# #           figsize=(20,10))

# sns.relplot(data = loc_110_total[loc_110_total['發生市區鄉鎮名稱'].isin('發生市區鄉鎮名稱')],
#             x='事故位置子類別名稱',
#             y='事故件數',
#             col='發生市區鄉鎮名稱',
#             facet_kws={'sharey':False, 'sharex':False})

# plt.show()

# %% [markdown]
# 桃園市交通事故發生時的年齡

# %%
total_0_9=sum(table_109.where('當事者事故發生時年齡',are.between(0,10)).group('當事者事故發生時年齡').column('count'))
total_10_19=sum(table_109.where('當事者事故發生時年齡',are.between(10,20)).group('當事者事故發生時年齡').column('count'))
total_20_29=sum(table_109.where('當事者事故發生時年齡',are.between(20,30)).group('當事者事故發生時年齡').column('count'))
total_30_39=sum(table_109.where('當事者事故發生時年齡',are.between(30,40)).group('當事者事故發生時年齡').column('count'))
total_40_49=sum(table_109.where('當事者事故發生時年齡',are.between(40,50)).group('當事者事故發生時年齡').column('count'))
total_50_59=sum(table_109.select('當事者事故發生時年齡').where('當事者事故發生時年齡',are.between(50,60)).group('當事者事故發生時年齡').column('count'))
total_60_69=sum(table_109.select('當事者事故發生時年齡').where('當事者事故發生時年齡',are.between(60,70)).group('當事者事故發生時年齡').column('count'))
total_70=sum(table_109.select('當事者事故發生時年齡').where('當事者事故發生時年齡',are.above(70)).group('當事者事故發生時年齡').column('count'))

# %%
total1_0_9=sum(table_110.where('當事者事故發生時年齡',are.between(0,10)).group('當事者事故發生時年齡').column('count'))
total1_10_19=sum(table_110.where('當事者事故發生時年齡',are.between(10,20)).group('當事者事故發生時年齡').column('count'))
total1_20_29=sum(table_110.where('當事者事故發生時年齡',are.between(20,30)).group('當事者事故發生時年齡').column('count'))
total1_30_39=sum(table_110.where('當事者事故發生時年齡',are.between(30,40)).group('當事者事故發生時年齡').column('count'))
total1_40_49=sum(table_110.where('當事者事故發生時年齡',are.between(40,50)).group('當事者事故發生時年齡').column('count'))
total1_50_59=sum(table_110.where('當事者事故發生時年齡',are.between(50,60)).group('當事者事故發生時年齡').column('count'))
total1_60_69=sum(table_110.where('當事者事故發生時年齡',are.between(60,70)).group('當事者事故發生時年齡').column('count'))
total1_70=sum(table_110.where('當事者事故發生時年齡',are.above(70)).group('當事者事故發生時年齡').column('count'))

# %%
happen_total = Table().with_columns(
  '年齡區間',make_array('0-9','10-19','20-29','30-39','40-49','50-59','60-69','70以上'),
  '109年的發生事故總共人數',make_array(total_0_9,total_10_19,total_20_29,total_30_39,total_40_49,total_50_59,total_60_69,total_70),
  '110年的發生事故總共人數',make_array(total1_0_9,total1_10_19,total1_20_29,total1_30_39,total1_40_49,total1_50_59,total1_60_69,total1_70)
  )
happen_total
# Out:
# 年齡區間  | 109年的發生事故總共人數 | 110年的發生事故總共人數
# 0-9   | 924           | 702
# 10-19 | 10718         | 7969
# 20-29 | 26631         | 22404
# 30-39 | 20000         | 16860
# 40-49 | 17625         | 15158
# 50-59 | 13858         | 12008
# 60-69 | 9934          | 8578
# 70以上  | 3735          | 3302

# %%
happen_total.plot('年齡區間')

# %%
drunk_name=make_array('經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%','經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%','經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%')
drunk_table109=table_109n.select('當事者事故發生時年齡','死亡人數_24小時內','死亡人數_2_30日內','飲酒情形名稱').where('飲酒情形名稱',are.equal_to(drunk_name)).to_df()

df=drunk_table109[(drunk_table109['死亡人數_24小時內'] > 0) | (drunk_table109['死亡人數_2_30日內'] >0) ]
df
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/predicates.py:261: SyntaxWarning: Do not pass an array or list to a predicate.                 If you are trying to find rows where two columns are the                 same, use table.where('c', are.equal_to, table.column('d'))                instead of table.where('c', are.equal_to(table.column('d'))).
#   SyntaxWarning)
#      當事者事故發生時年齡  死亡人數_24小時內  死亡人數_2_30日內                               飲酒情形名稱
# 44           19           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 49           57           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 95           49           1            0  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 171          38           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 285          54           1            0  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 402          31           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 472          38           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 482          19           1            0  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 538          28           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 564          30           1            0  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%

# %%
total_18=0
total_26=0
total_30=0
total_40=0
total_50=0
total_60=0

for i in df.index:
  if 18<= df['當事者事故發生時年齡'][i] <=25:
    total_18+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]
  elif 26<= df['當事者事故發生時年齡'][i] <=29 :
    total_26+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]
  elif 30<= df['當事者事故發生時年齡'][i] <=39:
    total_30+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]
  elif 40<= df['當事者事故發生時年齡'][i] <=49:
    total_40+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]
  elif 50<= df['當事者事故發生時年齡'][i] <=59:
    total_50+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]
  elif df['當事者事故發生時年齡'][i] >=60:
    total_60+=df['死亡人數_24小時內'][i]+df['死亡人數_2_30日內'][i]

# %%
df_i109=table_109n.select('當事者事故發生時年齡','受傷人數','飲酒情形名稱').where('飲酒情形名稱',are.equal_to(drunk_name)).to_df()
df_i109
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/predicates.py:261: SyntaxWarning: Do not pass an array or list to a predicate.                 If you are trying to find rows where two columns are the                 same, use table.where('c', are.equal_to, table.column('d'))                instead of table.where('c', are.equal_to(table.column('d'))).
#   SyntaxWarning)
#      當事者事故發生時年齡  受傷人數                               飲酒情形名稱
# 0            15     1  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 1            21     2  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 2            39     1  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 3            55     1  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 4            53     2  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# ..          ...   ...                                  ...
# 605          57     1  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 606          61     1  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 607          18     3  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 608          38     1  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 609          25     1  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
#
# [610 rows x 3 columns]

# %%
totali_18=0
totali_26=0
totali_30=0
totali_40=0
totali_50=0
totali_60=0

for i in df_i109.index:
  if 18<= df_i109['當事者事故發生時年齡'][i] <=25:
    totali_18+=df_i109['受傷人數'][i]
  elif 26<= df_i109['當事者事故發生時年齡'][i] <=29 :
    totali_26+=df_i109['受傷人數'][i]
  elif 30<= df_i109['當事者事故發生時年齡'][i] <=39:
    totali_30+=df_i109['受傷人數'][i]
  elif 40<= df_i109['當事者事故發生時年齡'][i] <=49:
    totali_40+=df_i109['受傷人數'][i]
  elif 50<= df_i109['當事者事故發生時年齡'][i] <=59:
    totali_50+=df_i109['受傷人數'][i]
  elif df_i109['當事者事故發生時年齡'][i] >=60:
    totali_60+=df_i109['受傷人數'][i]

# %%
drunk_table110=table_110n.select('當事者事故發生時年齡','死亡人數_24小時內','死亡人數_2_30日內','飲酒情形名稱').where('飲酒情形名稱',are.equal_to(drunk_name)).to_df()
df1=drunk_table110[(drunk_table110['死亡人數_24小時內'] > 0) | (drunk_table110['死亡人數_2_30日內'] >0) ]
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/predicates.py:261: SyntaxWarning: Do not pass an array or list to a predicate.                 If you are trying to find rows where two columns are the                 same, use table.where('c', are.equal_to, table.column('d'))                instead of table.where('c', are.equal_to(table.column('d'))).
#   SyntaxWarning)
#      當事者事故發生時年齡  死亡人數_24小時內  死亡人數_2_30日內                               飲酒情形名稱
# 62           41           1            0  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 182          42           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 210          25           1            0  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 215          37           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 231          44           0            1  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 232          47           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 323          20           1            0  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 349          20           1            0  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%

# %%
total1_18=0
total1_26=0
total1_30=0
total1_40=0
total1_50=0
total1_60=0

for i in df1.index:
  if 18<= df1['當事者事故發生時年齡'][i] <=25:
    total1_18+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]
  elif 26<= df1['當事者事故發生時年齡'][i] <=29 :
    total1_26+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]
  elif 30<= df1['當事者事故發生時年齡'][i] <=39:
    total1_30+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]
  elif 40<= df1['當事者事故發生時年齡'][i] <=49:
    total1_40+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]
  elif 50<= df1['當事者事故發生時年齡'][i] <=59:
    total1_50+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]
  elif df1['當事者事故發生時年齡'][i] >=60:
    total1_60+=df1['死亡人數_24小時內'][i]+df1['死亡人數_2_30日內'][i]

# %%
df_i110=table_110n.select('當事者事故發生時年齡','受傷人數','飲酒情形名稱').where('飲酒情形名稱',are.equal_to(drunk_name)).to_df()
df_i110
# Out:
# /usr/local/lib/python3.7/dist-packages/datascience/predicates.py:261: SyntaxWarning: Do not pass an array or list to a predicate.                 If you are trying to find rows where two columns are the                 same, use table.where('c', are.equal_to, table.column('d'))                instead of table.where('c', are.equal_to(table.column('d'))).
#   SyntaxWarning)
#      當事者事故發生時年齡  受傷人數                               飲酒情形名稱
# 0            18     2  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 1            34     1  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 2            22     2  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 3            33     2  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 4            62     1  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# ..          ...   ...                                  ...
# 461          53     2  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 462          49     1  經呼氣檢測0.26~0.40mg/L或血液檢測0.051%~0.08%
# 463          39     2  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
# 464          35     1  經呼氣檢測0.41~0.55mg/L或血液檢測0.081%~0.11%
# 465          22     2  經呼氣檢測0.56~0.80mg/L或血液檢測0.111%~0.16%
#
# [466 rows x 3 columns]

# %%
totali1_18=0
totali1_26=0
totali1_30=0
totali1_40=0
totali1_50=0
totali1_60=0

for i in df_i110.index:
  if 18<= df_i110['當事者事故發生時年齡'][i] <=25:
    totali1_18+=df_i110['受傷人數'][i]
  elif 26<= df_i110['當事者事故發生時年齡'][i] <=29 :
    totali1_26+=df_i110['受傷人數'][i]
  elif 30<= df_i110['當事者事故發生時年齡'][i] <=39:
    totali1_30+=df_i110['受傷人數'][i]
  elif 40<= df_i110['當事者事故發生時年齡'][i] <=49:
    totali1_40+=df_i110['受傷人數'][i]
  elif 50<= df_i110['當事者事故發生時年齡'][i] <=59:
    totali1_50+=df_i110['受傷人數'][i]
  elif df_i109['當事者事故發生時年齡'][i] >=60:
    totali1_60+=df_i110['受傷人數'][i]

# %%
die_inj_result=Table().with_columns(
  '年齡區間',make_array('18-25','26-29','30-39','40-49','50-59','60以上'),
  '109年死亡人數',make_array(total_18,total_26,total_30,total_40,total_50,total_60),
  '110年死亡人數',make_array(total1_18,total1_26,total1_30,total1_40,total1_50,total1_60),
  '109年受傷人數',make_array(totali_18,totali_26,totali_30,totali_40,totali_50,totali_60),
  '110年受傷人數',make_array(totali1_18,totali1_26,totali1_30,totali1_40,totali1_50,totali1_60)
)
die_inj_result
# Out:
# 年齡區間  | 109年死亡人數 | 110年死亡人數 | 109年受傷人數 | 110年受傷人數
# 18-25 | 2        | 3        | 114      | 83
# 26-29 | 1        | 0        | 60       | 35
# 30-39 | 4        | 1        | 154      | 123
# 40-49 | 1        | 4        | 174      | 145
# 50-59 | 2        | 0        | 149      | 125
# 60以上  | 0        | 0        | 131      | 19

# %%
die_inj_result.barh('年齡區間')
# plot
